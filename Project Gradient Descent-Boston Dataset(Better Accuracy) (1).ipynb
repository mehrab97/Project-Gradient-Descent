# %% [markdown]
# ### Gradient Descent - Boston Dataset
# Boston dataset is one of the datasets available in sklearn. You are given a Training dataset csv file with X train and Y train data. As studied in lecture, your task is to come up with Gradient Descent algorithm and thus predictions for the test dataset given. Your task is to:
#
# Code Gradient Descent for N features and come with predictions.
# Try and test with various combinations of learning rates and number of iterations.
# Try using Feature Scaling, and see if it helps you in getting better results. Read Instructions carefully -
# Use Gradient Descent as a training algorithm and submit results predicted.
# Files are in csv format, you can use genfromtxt function in numpy to load data from csv file. Similarly you can use savetxt function to save data into a file.
# Submit a csv file with only predictions for X test data. File name should not have spaces. File should not have any headers and should only have one column i.e. predictions. Also predictions shouldn't be in exponential form.
# Your score is based on coefficient of determination.

# %%
import numpy as np
import pandas as pd 

training_data=np.loadtxt('/Users/shabeggill/Downloads/0000000000002417_training_boston_x_y_train.csv',delimiter=',')
testing_data=np.loadtxt('/Users/shabeggill/Downloads/0000000000002417_test_boston_x_test.csv',delimiter=',')

df=pd.DataFrame(training_data[:,0:13]) #Features
column_names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM' ,'AGE', 'DIS' ,'RAD', 'TAX', 'PTRATIO',
 'B', 'LSTAT']
df.columns=column_names
df
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
#Adding new features
for i in df.iloc[:,:13]:
    for j in df.iloc[:,:13]:
        df[i+'_'+j] = df[i].astype('float') * df[j].astype('float')
    
df.head()
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1 -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2  0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3  0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4 -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
#
#         DIS       RAD       TAX  ...  LSTAT_CHAS  LSTAT_NOX  LSTAT_RM  \
# 0 -0.520264 -0.752922 -1.278354  ...    0.299311   0.632589 -1.361479
# 1  0.336351 -0.523001 -0.060801  ...    0.141881   0.529160 -0.001013
# 2 -0.577309  1.661245  1.530926  ...   -0.242906   1.218538 -0.391805
# 3 -0.712836  1.661245  1.530926  ...   -0.058728   0.400688 -0.010323
# 4  0.300508 -0.752922 -0.957633  ...   -0.007907  -0.026484 -0.011143
#
#    LSTAT_AGE  LSTAT_DIS  LSTAT_RAD  LSTAT_TAX  LSTAT_PTRATIO   LSTAT_B  \
# ...

# %%
len(df.columns)
# Out:
# 182

# %%
X_train_with_new_features=df.values
X_train_with_new_features
# Out:
# array([[-0.40784991, -0.48772236, -1.2660231 , ...,  0.33279438,
#         -0.45080292,  1.20558228],
#        [-0.40737368, -0.48772236,  0.24705682, ..., -0.05883028,
#         -0.15154601,  0.27089331],
#        [ 0.1251786 , -0.48772236,  1.01599907, ...,  0.71872027,
#         -3.38234174,  0.79401622],
#        ...,
#        [-0.40831101, -0.48772236,  0.24705682, ..., -0.03775758,
#         -0.11092439,  0.11158472],
#        [-0.41061997, -0.48772236, -1.15221381, ...,  0.53564095,
#         -0.15135971,  0.55465581],
#        [ 0.34290895, -0.48772236,  1.01599907, ..., -1.09590535,
#         -0.52701066,  1.84610197]])

# %%
print(len(X_train_with_new_features)) #rows
print(len(X_train_with_new_features[0])) #columns
# Out:
# 379
# 182

# %%
df_test=pd.DataFrame(testing_data)
df_test
# Out:
#             0         1         2         3         4         5         6  \
# 0    2.918166 -0.487722  1.015999 -0.272599  0.365444 -1.609343  1.117494
# 1   -0.403392 -0.487722  0.406098 -0.272599 -1.016689  0.560412 -1.332629
# 2   -0.413178 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 3   -0.412649  0.413589 -0.802031 -0.272599 -0.999412 -0.408356 -1.677566
# 4   -0.405882 -0.487722 -0.375976 -0.272599 -0.299707 -0.127698 -0.504068
# ..        ...       ...       ...       ...       ...       ...       ...
# 122 -0.408684 -0.487722  0.247057 -0.272599 -1.016689 -0.585014 -1.137046
# 123 -0.408903 -0.487722  0.406098 -0.272599 -1.016689 -0.392685 -0.934351
# 124 -0.410014  2.087452 -1.378373 -0.272599 -1.241285 -0.570767 -1.780692
# 125 -0.403176 -0.487722 -0.375976 -0.272599 -0.299707 -0.224575  0.591198
# 126 -0.133563 -0.487722  1.231945 -0.272599  2.732346 -1.442658  0.904131
#
#             7         8         9        10        11        12
# ...

# %%
column_names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM' ,'AGE', 'DIS' ,'RAD', 'TAX', 'PTRATIO',
 'B', 'LSTAT']
df_test.columns=column_names
df_test
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0    2.918166 -0.487722  1.015999 -0.272599  0.365444 -1.609343  1.117494
# 1   -0.403392 -0.487722  0.406098 -0.272599 -1.016689  0.560412 -1.332629
# 2   -0.413178 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 3   -0.412649  0.413589 -0.802031 -0.272599 -0.999412 -0.408356 -1.677566
# 4   -0.405882 -0.487722 -0.375976 -0.272599 -0.299707 -0.127698 -0.504068
# ..        ...       ...       ...       ...       ...       ...       ...
# 122 -0.408684 -0.487722  0.247057 -0.272599 -1.016689 -0.585014 -1.137046
# 123 -0.408903 -0.487722  0.406098 -0.272599 -1.016689 -0.392685 -0.934351
# 124 -0.410014  2.087452 -1.378373 -0.272599 -1.241285 -0.570767 -1.780692
# 125 -0.403176 -0.487722 -0.375976 -0.272599 -0.299707 -0.224575  0.591198
# 126 -0.133563 -0.487722  1.231945 -0.272599  2.732346 -1.442658  0.904131
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
#Adding new features
for i in df_test.iloc[:,:13]:
    for j in df_test.iloc[:,:13]:
        df_test[i+'_'+j] = df_test[i].astype('float') * df_test[j].astype('float')
    
df_test.head()
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0  2.918166 -0.487722  1.015999 -0.272599  0.365444 -1.609343  1.117494
# 1 -0.403392 -0.487722  0.406098 -0.272599 -1.016689  0.560412 -1.332629
# 2 -0.413178 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 3 -0.412649  0.413589 -0.802031 -0.272599 -0.999412 -0.408356 -1.677566
# 4 -0.405882 -0.487722 -0.375976 -0.272599 -0.299707 -0.127698 -0.504068
#
#         DIS       RAD       TAX  ...  LSTAT_CHAS  LSTAT_NOX  LSTAT_RM  \
# 0 -1.048494  1.661245  1.530926  ...   -0.283792   0.380450 -1.675426
# 1  1.029344 -0.637962 -0.708183  ...    0.243904   0.909670 -0.501422
# 2 -0.716639 -0.982843 -0.803212  ...    0.136531  -0.079196  0.117473
# 3  1.435452 -0.637962 -0.981390  ...    0.161368   0.591615  0.241732
# 4 -0.483566 -0.523001 -0.143951  ...   -0.013257  -0.014575 -0.006210
#
#    LSTAT_AGE  LSTAT_DIS  LSTAT_RAD  LSTAT_TAX  LSTAT_PTRATIO   LSTAT_B  \
# ...

# %%
X_test_with_new_features=df_test.values
X_test_with_new_features
# Out:
# array([[ 2.91816626, -0.48772236,  1.01599907, ...,  0.8396953 ,
#         -1.66314958,  1.08380971],
#        [-0.40339151, -0.48772236,  0.40609801, ...,  1.01583792,
#         -0.39462597,  0.8005563 ],
#        [-0.4131781 , -0.48772236,  0.11573841, ..., -0.58923266,
#         -0.22090077,  0.25085051],
#        ...,
#        [-0.41001449,  2.08745172, -1.37837329, ...,  0.04902115,
#         -0.2664969 ,  0.4646794 ],
#        [-0.40317611, -0.48772236, -0.37597609, ...,  0.22765181,
#          0.06849723,  0.04057036],
#        [-0.13356344, -0.48772236,  1.2319449 , ..., -0.84872133,
#         -1.43648214,  0.23890307]])

# %%
print(len(X_test_with_new_features)) #rows
print(len(X_test_with_new_features[0])) #columns
# Out:
# 127
# 182

# %%
#Feature Scaling
from sklearn import preprocessing
scaler=preprocessing.StandardScaler()
scaler.fit(X_train_with_new_features)
trained=scaler.transform(X_train_with_new_features)
test=scaler.transform(X_test_with_new_features)


def step_gradient(X,Y,learning_rate,m):
    m_slope=np.zeros(len(X[0]))
    M=len(X)
    for i in range(M):
        x=X[i]
        y=Y[i]
        for j in range(len(X[0])):
            m_slope[j]+=(-2/M)*(y - sum(m * x))*x[j]
    new_m=m-learning_rate*m_slope
    return new_m

def gd(X,Y,learning_rate,num_iterations):
    m=np.zeros(len(X[0]))
    for i in range(num_iterations):
        #step gradient performs single step
        #to update values of m and c
        m=step_gradient(X,Y,learning_rate,m)
        print(i,"Cost:",cost(X,Y,m))
    return m

def cost(X,Y,m): #takes the current m
    total_cost=0
    M=len(X)
    for i in range(M):
        x=X[i]
        y=Y[i]
        total_cost+=(1/M)*((y-sum(m*x))**2)
    return total_cost

def run():
    learning_rate=0.07
    num_iterations=10
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run()
# Out:
# 0 Cost: 544.7683954653835
# 1 Cost: 2836.553868726196
# 2 Cost: 55997.98930737312
# 3 Cost: 1265051.2533424925
# 4 Cost: 28841230.641787045
# 5 Cost: 658252900.0201975
# 6 Cost: 15026199260.354969
# 7 Cost: 343019817945.78784
# 8 Cost: 7830540632941.952
# 9 Cost: 178757687675691.78
# [ 2.19276295e+05  1.00389804e+05  5.44643250e+04 -2.82827268e+04
#   6.45640963e+04 -2.31991061e+04  3.83395468e+03 -5.16933898e+03
#   1.80233323e+05  1.67876913e+05  4.44961591e+04 -1.61171271e+05
#   9.99580065e+04  1.46819991e+05 -2.61090646e+05  2.18193152e+05
#  -1.24129304e+05  2.19295407e+05 -1.39412591e+05  2.30300371e+05
#  -2.26118291e+05  2.07594744e+05  2.05056844e+05  2.17064520e+05
#  -1.43583670e+05  2.11229938e+05 -2.61090646e+05  1.16578691e+05
#  -1.53648218e+05  3.70931351e+04 -1.60728305e+05  1.09689640e+05
#  -1.40347859e+05  1.23291981e+05 -2.27546564e+05 -2.09259413e+05
#  -1.17263326e+05  2.05697559e+05 -1.81427887e+05  2.18193152e+05
# ...

# %%
#Reduce the learning rate
def run1():
    learning_rate=0.03
    num_iterations=10
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run1()
# Out:
# 0 Cost: 504.95588456590207
# 1 Cost: 453.4017448013625
# 2 Cost: 427.9910455721765
# 3 Cost: 440.722355644955
# 4 Cost: 526.1040977718028
# 5 Cost: 762.1156548937961
# 6 Cost: 1320.1207549534588
# 7 Cost: 2574.5214812724394
# 8 Cost: 5341.974160210948
# 9 Cost: 11402.798925503972
# [ 1.56134027  1.02647736 -0.09410436  0.13372583  0.03342428  1.42168854
#  -0.45063611  0.02155962  1.29480995  0.86234546 -0.27830263 -1.02635119
#  -0.59523862  1.18543937 -2.07232223  1.77231521 -0.84320927  1.62586001
#  -1.05891346  1.85467933 -1.69702468  1.49342331  1.57237289  1.80597587
#  -1.12373652  1.53889165 -2.07232223  1.047725   -1.24069362  0.38573425
#  -1.24269085  0.91679298 -1.23801414  0.98774768 -1.87459409 -1.71050549
#  -0.93993831  1.59508848 -1.28972108  1.77231521 -1.24069362  0.44900221
#  -0.30666274  1.08338742 -0.95357173  1.38149435 -0.98694499  1.74628568
#   1.32240754  0.90684554 -1.25407899  1.13032325 -0.84320927  0.38573425
# ...

# %%
#Reduce the learning rate

def run2():
    learning_rate=0.02
    num_iterations=10
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run2()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# [-1.75092539e-01  2.37784371e-01 -5.00102572e-01  3.08303986e-01
#  -4.24973866e-01  1.28024626e+00 -4.34646221e-01  1.06629460e-01
#  -1.53287784e-01 -4.15103505e-01 -5.74187854e-01  2.22061907e-01
#  -1.14717883e+00 -2.44797919e-03 -8.36287217e-03  2.70388663e-02
#   1.17204913e-01 -1.11210671e-01 -6.42154358e-03  1.25512051e-02
#   9.21512915e-02 -1.45709836e-01 -6.80928728e-02  7.16223341e-02
#   1.03399453e-02 -1.25540977e-01 -8.36287217e-03  1.31416086e-01
#  -3.66565356e-02  7.49366551e-02  4.83850347e-03  7.89474846e-02
#  -1.15740707e-01  1.72312788e-02 -8.19170062e-02 -5.96813978e-02
#  -4.80110832e-02 -1.59213862e-02  1.14729204e-01  2.70388663e-02
# ...

# %%
def run2():
    learning_rate=0.02
    num_iterations=2000
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run2()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
#Increasing the iterations
def run3():
    learning_rate=0.02
    num_iterations=1200
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run3()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
def run4():
    learning_rate=0.02
    num_iterations=1000
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run4()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
#1200 iterations
m=[6.19808531e-02,  1.42203803e-01,  3.28529323e-01,  9.79546425e-01,
 -1.31465248e+00,  3.16080878e+00 ,-1.67493873e+00, -2.66526198e+00,
  1.16337824e+00, -1.09648376e+00, -4.22810087e-01,  6.29556827e-01,
 -3.74301477e+00,  6.41982014e-01, -7.93765435e-02,  1.09214264e-01,
  1.22902584e+00, -3.01874240e-01,  4.43955464e-01,  9.34871359e-02,
 -2.70144999e-02, -5.33741469e-01,  1.93591659e-01, -3.94655462e-01,
 -1.72757505e-01,  7.31514802e-01, -7.93765435e-02, -8.81214291e-03,
 -8.02950998e-02, -2.58825990e-02,  2.34624952e-01, -9.50203156e-02,
 -3.59253069e-01, -2.99005739e-01,  2.82163395e-02,  7.03845092e-01,
 -1.72063154e-01,  6.78222277e-02, -4.95773734e-01,  1.09214264e-01,
 -8.02950998e-02,  8.65611675e-01, -2.21807582e-01,  1.33584408e+00,
  5.39551533e-01,  1.79242462e-01,  8.91130395e-01, -5.45730764e-01,
 -7.20840441e-02, -3.21020080e-01,  6.42672803e-02, -2.52781547e-01,
# ...

# %%
def run5():
    learning_rate=0.02
    num_iterations=700
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run5()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
#700 iterations
m=[-2.22719237e-02,  1.53076652e-01,  4.79564737e-02,  9.33663305e-01,
 -1.05236582e+00,  3.21137537e+00, -1.33136155e+00, -2.28251475e+00,
  8.86113683e-01, -1.05126266e+00, -4.43321396e-01,  6.66091535e-01,
 -3.64958474e+00,  4.56463956e-01, -4.44510479e-02,  1.06899370e-01,
  1.14461880e+00, -2.51338811e-01,  4.16425638e-01,  1.37072501e-01,
  6.51740761e-02, -4.16599701e-01,  1.86739650e-01, -2.67872485e-01,
 -1.41953173e-01,  6.13714605e-01, -4.44510479e-02,  1.44635341e-03,
 -7.70510862e-02, -7.68599649e-03,  2.21802238e-01, -7.67586185e-02,
 -2.39303810e-01, -1.39256555e-01,  2.82679117e-02,  6.14618467e-01,
 -9.23617899e-02,  9.06148719e-02, -4.53381218e-01,  1.06899370e-01,
 -7.70510862e-02,  7.20868441e-01, -1.90972827e-01,  1.09153653e+00,
  4.75959089e-01,  1.66542567e-01,  6.48694483e-01, -4.15159172e-01,
 -1.06498582e-01, -3.15321878e-01,  3.48375570e-02, -2.78055932e-01,
  1.14461880e+00, -7.68599649e-03, -1.90972827e-01,  9.33663305e-01,
 -4.83095684e-01, -6.45127011e-01,  5.80790710e-02,  5.69025038e-02,
 -2.76104027e-01,  9.53861241e-02, -2.06780237e-02,  9.25629099e-02,
 -3.26819859e-01, -2.51338811e-01,  2.21802238e-01,  1.09153653e+00,
 -4.83095684e-01, -4.85065616e-01,  2.76792595e-01, -7.91857271e-01,
  4.84038824e-01, -7.53973328e-01,  1.70843329e-01, -5.05668035e-01,
#  -3.09171437e-02  1.04143418e+00 -1.03974221e-01  2.54843701e+00
#   4.99643398e-02 -1.78220557e-03 -3.63695410e-01 -5.18063633e-01
#  -1.24958843e+00  6.31110194e-01 -3.51646048e-01  1.24979264e+00
#   9.36396976e-01  4.00574899e-01 -1.29298286e+00  4.68445689e-01
#  -1.64310888e+00  2.10161618e-01 -3.63695410e-01 -2.87849167e-01
# ...

# %%
#500 iterations
def run6():
    learning_rate=0.02
    num_iterations=500
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run6()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
#500 iterations
m=[-5.81377430e-02,  1.65018657e-01, -8.54108704e-02,  8.98195559e-01,
 -9.11131625e-01,  3.23715676e+00, -1.10538561e+00, -1.98671126e+00,
  7.12196745e-01, -1.01919683e+00, -4.93741755e-01,  6.66002497e-01,
 -3.52855591e+00,  3.53377468e-01, -3.48890706e-02,  1.06891937e-01,
  1.06354604e+00, -2.24427772e-01,  3.82359365e-01,  1.39063429e-01,
  9.52811146e-02, -3.55402268e-01,  1.76195781e-01, -1.89127386e-01,
 -1.20020754e-01,  5.12133715e-01, -3.48890706e-02,  3.37305578e-02,
 -7.77334179e-02,  1.44663971e-02,  2.04789533e-01, -6.16629630e-02,
 -1.83930088e-01, -5.02652126e-02,  4.34030360e-02,  5.41962424e-01,
 -3.67662547e-02,  7.87169832e-02, -3.91684411e-01,  1.06891937e-01,
 -7.77334179e-02,  6.34588284e-01, -1.72851644e-01,  9.15957182e-01,
  4.30879552e-01,  1.72556436e-01,  5.02539396e-01, -3.20864091e-01,
 -1.06940079e-01, -2.93565141e-01,  2.98448615e-02, -2.94619043e-01,
  1.06354604e+00,  1.44663971e-02, -1.72851644e-01,  8.98195559e-01,
#   1.00848766e+00  1.03550655e+00 -2.03001275e+00  2.54843701e+00
#  -1.64310888e+00  6.20781123e-01 -3.92730164e+00  2.89782852e+00
#  -2.50019513e+00  2.67135764e+00  2.65421778e+00  2.48890637e+00
#  -1.93172073e+00  1.68954557e+00 -2.03001275e+00 -3.09309549e-01
#   4.99643398e-02  2.10161618e-01  3.24779220e-01  5.18945033e-01
#   1.13136237e-02 -1.10402357e-01 -6.38771053e-01 -5.71983777e-01
#  -3.09171437e-02  1.04143418e+00 -1.03974221e-01  2.54843701e+00
#   4.99643398e-02 -1.78220557e-03 -3.63695410e-01 -5.18063633e-01
#  -1.24958843e+00  6.31110194e-01 -3.51646048e-01  1.24979264e+00
#   9.36396976e-01  4.00574899e-01 -1.29298286e+00  4.68445689e-01
#  -1.64310888e+00  2.10161618e-01 -3.63695410e-01 -2.87849167e-01
# ...

# %%
#300 iterations
def run7():
    learning_rate=0.02
    num_iterations=300
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run7()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
# 300 iterations
m=[-9.37870557e-02,  1.71642659e-01, -2.37287440e-01,  8.33479915e-01,
 -7.58276191e-01,  3.24886725e+00, -8.02341215e-01, -1.51350593e+00,
  4.72018760e-01, -9.70177427e-01, -5.79315403e-01,  6.26591133e-01,
 -3.26073263e+00,  2.33941574e-01, -2.24596340e-02,  1.06703551e-01,
  9.07279279e-01, -1.90080187e-01,  3.19771300e-01,  1.18815380e-01,
  1.16895465e-01, -2.80136465e-01,  1.56141178e-01, -8.38428952e-02,
 -8.97891426e-02,  3.40939723e-01, -2.24596340e-02,  8.61219287e-02,
 -6.85960472e-02,  5.73226186e-02,  1.82836552e-01, -3.66247535e-02,
 -1.48725785e-01,  4.93787913e-02,  6.63047395e-02,  3.97767952e-01,
 -5.19345717e-01,  9.98905855e-01,  2.26093901e+01]
X_test=np.append(test,np.ones(len(X_test_with_new_features[:,0])).reshape(-1, 1),axis=1)
print(X_test[0])
print(len(m))
print(len(X_test[0]))
# Out:
# [ 2.71887193e+00 -4.90426876e-01  9.64253278e-01 -2.87849167e-01
#   3.37230164e-01 -1.64178699e+00  1.09674705e+00 -1.02022479e+00
#   1.59414810e+00  1.45994481e+00  7.88165823e-01 -1.55922624e+00
#   1.00848766e+00  1.03550655e+00 -2.03001275e+00  2.54843701e+00
#  -1.64310888e+00  6.20781123e-01 -3.92730164e+00  2.89782852e+00
#  -2.50019513e+00  2.67135764e+00  2.65421778e+00  2.48890637e+00
#  -1.93172073e+00  1.68954557e+00 -2.03001275e+00 -3.09309549e-01
#   4.99643398e-02  2.10161618e-01  3.24779220e-01  5.18945033e-01
#   1.13136237e-02 -1.10402357e-01 -6.38771053e-01 -5.71983777e-01
#  -3.09171437e-02  1.04143418e+00 -1.03974221e-01  2.54843701e+00
#   4.99643398e-02 -1.78220557e-03 -3.63695410e-01 -5.18063633e-01
#  -1.24958843e+00  6.31110194e-01 -3.51646048e-01  1.24979264e+00
#   9.36396976e-01  4.00574899e-01 -1.29298286e+00  4.68445689e-01
#  -1.64310888e+00  2.10161618e-01 -3.63695410e-01 -2.87849167e-01
# ...

# %%
#200 iterations
def run8():
    learning_rate=0.02
    num_iterations=200
    X=np.append(trained,np.ones(len(X_train_with_new_features[:,0])).reshape(-1, 1), axis=1)
    Y=training_data[:,13]
    m=gd(X,Y,learning_rate,num_iterations)
    print(m)
    
run8()
# Out:
# 0 Cost: 524.5327015405549
# 1 Cost: 474.54433951557775
# 2 Cost: 433.6277716507038
# 3 Cost: 398.1134005727805
# 4 Cost: 366.4356982451645
# 5 Cost: 337.79054549052404
# 6 Cost: 311.6987403901286
# 7 Cost: 287.83549147606726
# 8 Cost: 265.9573059246801
# 9 Cost: 245.86819588831295
# 10 Cost: 227.40290714783515
# 11 Cost: 210.41795255330445
# 12 Cost: 194.7864230643307
# 13 Cost: 180.3947339514287
# 14 Cost: 167.14042504740948
# 15 Cost: 154.93057334350252
# 16 Cost: 143.68058480395476
# 17 Cost: 133.3132354422856
# 18 Cost: 123.75788512248397
# 19 Cost: 114.949816607091
# 20 Cost: 106.8296689937693
# 21 Cost: 99.3429446518928
# 22 Cost: 92.43957501301931
# 23 Cost: 86.0735346239835
# 24 Cost: 80.20249558842868
# 25 Cost: 74.78751639203651
# 26 Cost: 69.7927604231222
# 27 Cost: 65.18524044707246
# 28 Cost: 60.93458598787961
# 29 Cost: 57.01283108996452
# 30 Cost: 53.394220330150766
# 31 Cost: 50.0550312581524
# 32 Cost: 46.97341168838001
# 33 Cost: 44.129230463081335
# ...

# %%
#200 iterations
m=[-1.11977152e-01,  1.66493598e-01, -3.20278849e-01,  7.71796403e-01,
 -6.85574767e-01,  3.21748482e+00, -6.25314765e-01, -1.15757598e+00,
  3.16400655e-01, -9.19630645e-01, -6.33875611e-01,  5.71881605e-01,
 -2.46376184e-02, -1.98857620e-01, -2.94169382e-01, -3.54193268e-01,
 -9.60710002e-02, -2.27711015e-01,  9.52498376e-02, -7.45993013e-01,
 -5.60990355e-01,  2.16635186e-01, -1.56383680e-01, -3.35282311e-01,
 -2.58256505e-01,  2.71954145e-01, -6.16874104e-01, -6.07255947e-01,
  4.89640850e-01, -5.29358273e-01, -5.81152957e-01, -7.39408826e-02,
 -5.60990355e-01,  8.72491658e-01,  2.26030638e+01]
X_test=np.append(test,np.ones(len(X_test_with_new_features[:,0])).reshape(-1, 1),axis=1)
print(X_test[0])
print(len(m))
#print(len(X_test[0]))
# Out:
# [ 2.71887193e+00 -4.90426876e-01  9.64253278e-01 -2.87849167e-01
#   3.37230164e-01 -1.64178699e+00  1.09674705e+00 -1.02022479e+00
#   1.59414810e+00  1.45994481e+00  7.88165823e-01 -1.55922624e+00
#   1.00848766e+00  1.03550655e+00 -2.03001275e+00  2.54843701e+00
#  -1.64310888e+00  6.20781123e-01 -3.92730164e+00  2.89782852e+00
#  -2.50019513e+00  2.67135764e+00  2.65421778e+00  2.48890637e+00
#  -1.93172073e+00  1.68954557e+00 -2.03001275e+00 -3.09309549e-01
#   4.99643398e-02  2.10161618e-01  3.24779220e-01  5.18945033e-01
#   1.13136237e-02 -1.10402357e-01 -6.38771053e-01 -5.71983777e-01
#  -3.09171437e-02  1.04143418e+00 -1.03974221e-01  2.54843701e+00
#   4.99643398e-02 -1.78220557e-03 -3.63695410e-01 -5.18063633e-01
#  -1.24958843e+00  6.31110194e-01 -3.51646048e-01  1.24979264e+00
#   9.36396976e-01  4.00574899e-01 -1.29298286e+00  4.68445689e-01
#  -1.64310888e+00  2.10161618e-01 -3.63695410e-01 -2.87849167e-01
# ...

# %%
Y_pred_arr=[]
for i in range(len(X_test)):
    Y_pred=sum(m * X_test[i])
    Y_pred_arr.append(Y_pred)

print(Y_pred_arr)
# Out:
# [16.92864735169752, 28.53310998417735, 19.571242570590666, 22.580380866987024, 21.32026983234647, 9.076068295471575, 27.95471138292782, 24.899256080420457, 17.705379841627433, 21.684383903001546, 23.97736435682886, 16.848285381340254, 19.09861877225867, 19.158190996402155, 47.555705077420015, 21.057356748141547, 21.836270690516702, 26.305258744870763, 18.948715120585653, 30.764691410510252, 21.25161154929241, 21.373659801873387, 37.00633126702903, 34.47209516627572, 32.90390265353536, 20.85162465775424, 19.939812462436237, 27.723608114959298, 21.039741408873574, 29.782598284133755, 17.028743547177395, 22.829429132714132, 22.065629481722123, 24.055236821925824, 8.918257584676583, 26.636678774462094, 23.917389826207838, 19.28652062198392, 21.41953130912674, 8.801936588083352, 18.602191356319757, 26.293240460494722, 23.299867286036545, 20.034145592394758, 19.682529273496964, 12.887726092532722, 46.643822477621256, 24.247115528345862, 34.510630797534105, 11.728210131354457, 17.5725430627
# ...

# %%
#fmt is used for converting exponential form to decimal format in csv, here taken upto 15 decimal places
np.savetxt('PredictionsForBostonDatasetBetterAccuracy(1).csv',Y_pred_arr,delimiter=',',fmt='%.15f')
